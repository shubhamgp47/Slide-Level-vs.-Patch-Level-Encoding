# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_rel
import ast
import os


# ========== CONFIGURATION ==========
MODEL_CONFIGS = {
    'TITAN': {
        'base_dir': '/home/woody/iwi5/iwi5204h/HistGen4TITAN/Data/TestResults',
        'seeds': {
            'seed43': {'seed_folder': '5_seed43', 'best_folder': 'Best17'},
            'seed44': {'seed_folder': '5_seed44', 'best_folder': 'Best30'},
            'seed45': {'seed_folder': '5_seed45', 'best_folder': 'Best40'},
            'seed46': {'seed_folder': '5_seed46', 'best_folder': 'Best37'},
            'seed456789': {'seed_folder': '5', 'best_folder': 'Best33'}
        }
    },
    'CONCH': {
        'base_dir': '/home/woody/iwi5/iwi5204h/HistGen/Data/TestResult_conch',
        'seeds': {
            'seed43': {'seed_folder': 'seed43', 'best_folder': 'Best_11'},
            'seed44': {'seed_folder': 'seed44', 'best_folder': 'Best_35'},
            'seed45': {'seed_folder': 'seed45', 'best_folder': 'Best_37'},
            'seed46': {'seed_folder': 'seed46', 'best_folder': 'Best_27'},
            'seed456789': {'seed_folder': 'seed42', 'best_folder': 'Best_40'}
        }
    },
    'UNI': {
        'base_dir': '/home/woody/iwi5/iwi5204h/HistGen/Data/TestResult_UNI1',
        'seeds': {
            'seed43': {'seed_folder': '1_seed43', 'best_folder': 'Best_15'},
            'seed44': {'seed_folder': '1_seed44', 'best_folder': 'Best_27'},
            'seed45': {'seed_folder': '1_seed45', 'best_folder': 'Best_38'},
            'seed46': {'seed_folder': '1_seed46', 'best_folder': 'Best_40'},
            'seed456789': {'seed_folder': '1', 'best_folder': 'Best_38'}
        }
    },
    'UNI2': {
        'base_dir': '/home/woody/iwi5/iwi5204h/HistGen/Data/TestResult_UNI2',
        'seeds': {
            'seed43': {'seed_folder': '4_seed43', 'best_folder': 'Best_34'},
            'seed44': {'seed_folder': '4_seed44', 'best_folder': 'Best_16'},
            'seed45': {'seed_folder': '4_seed45', 'best_folder': 'Best_38'},
            'seed46': {'seed_folder': '4_seed46', 'best_folder': 'Best_25'},
            'seed456789': {'seed_folder': '4', 'best_folder': 'Best_27'}
        }
    }
}


METRICS = ['test_BLEU_1', 'test_BLEU_2', 'test_BLEU_3', 'test_BLEU_4',
           'test_METEOR', 'test_ROUGE_L']


N_BOOTSTRAP = 10000
CI_LEVEL = 0.95


def load_scores_from_txt(txt_path):
    try:
        with open(txt_path, 'r') as f:
            content = f.read().strip()
        scores_dict = ast.literal_eval(content)
        scores = {}
        for metric in METRICS:
            if metric in scores_dict:
                scores[metric] = float(scores_dict[metric])
            else:
                scores[metric] = None
        return scores
    except Exception as e:
        print(f"    ERROR loading {txt_path}: {e}")
        return None


def load_scores_from_csv(csv_path):
    try:
        df = pd.read_csv(csv_path)
        scores = {}
        for metric in METRICS:
            if metric in df.columns:
                scores[metric] = float(df[metric].iloc[0])
            else:
                scores[metric] = None
        return scores
    except Exception as e:
        print(f"    ERROR loading {csv_path}: {e}")
        return None


def load_scores_for_model_seed(base_dir, seed_folder, best_folder):
    folder_path = os.path.join(base_dir, seed_folder, best_folder)

    txt_path = os.path.join(folder_path, 'results.txt')
    if os.path.exists(txt_path):
        return load_scores_from_txt(txt_path)

    csv_path = os.path.join(folder_path, 'results.csv')
    if os.path.exists(csv_path):
        return load_scores_from_csv(csv_path)

    print(f"    WARNING: Neither results.txt nor results.csv found in {folder_path}")
    return None


def load_all_scores(model_configs):
    all_scores = {}

    for model, config in model_configs.items():
        all_scores[model] = {}

        for seed_name, seed_config in config['seeds'].items():
            seed_folder = seed_config['seed_folder']
            best_folder = seed_config['best_folder']

            scores = load_scores_for_model_seed(
                config['base_dir'],
                seed_folder,
                best_folder
            )

            if scores:
                all_scores[model][seed_name] = scores

    return all_scores


def cohens_d(group1, group2):
    diffs = np.array(group1) - np.array(group2)
    return np.mean(diffs) / np.std(diffs, ddof=1)


def interpret_cohens_d(d):
    abs_d = abs(d)
    if abs_d < 0.2:
        return "negligible"
    elif abs_d < 0.5:
        return "small"
    elif abs_d < 0.8:
        return "medium"
    else:
        return "large"


def bootstrap_ci(group1, group2, n_bootstrap=10000, ci_level=0.95):
    diffs = np.array(group1) - np.array(group2)
    n = len(diffs)
    observed_mean = np.mean(diffs)

    bootstrap_means = np.zeros(n_bootstrap)
    for i in range(n_bootstrap):
        resample_indices = np.random.choice(n, size=n, replace=True)
        resample_diffs = diffs[resample_indices]
        bootstrap_means[i] = np.mean(resample_diffs)

    alpha = 1 - ci_level
    ci_lower = np.percentile(bootstrap_means, 100 * alpha / 2)
    ci_upper = np.percentile(bootstrap_means, 100 * (1 - alpha / 2))

    return observed_mean, ci_lower, ci_upper


# ========== PAIRED T-TEST ANALYSIS WITH BOOTSTRAP CI ==========
def perform_paired_ttest_analysis(all_scores, baseline_model='TITAN'):
    print("="*70)
    print(f"PAIRED T-TEST ANALYSIS WITH BOOTSTRAP CI (Baseline: {baseline_model})")
    print("="*70)

    seeds = sorted(all_scores[baseline_model].keys())
    print(f"\nSeeds: {seeds}")
    print(f"Number of seeds: {len(seeds)}")
    print(f"Bootstrap iterations: {N_BOOTSTRAP}")
    print(f"Confidence level: {CI_LEVEL*100}%\n")

    np.random.seed(42)

    comparison_models = [m for m in sorted(all_scores.keys()) if m != baseline_model]
    results = []

    for metric in METRICS:
        print(f"\n{'='*70}")
        print(f"Metric: {metric}")
        print(f"{'='*70}")

        baseline_scores = []
        for seed in seeds:
            if seed in all_scores[baseline_model]:
                score = all_scores[baseline_model][seed].get(metric)
                if score is not None:
                    baseline_scores.append(score)
                else:
                    print(f"  WARNING: Missing {metric} for {baseline_model}/{seed}")
                    baseline_scores.append(np.nan)
            else:
                print(f"  WARNING: Missing data for {baseline_model}/{seed}")
                baseline_scores.append(np.nan)

        baseline_scores = np.array(baseline_scores)

        for model in comparison_models:
            print(f"\n--- {baseline_model} vs {model} ---")

            model_scores = []
            for seed in seeds:
                if seed in all_scores[model]:
                    score = all_scores[model][seed].get(metric)
                    if score is not None:
                        model_scores.append(score)
                    else:
                        print(f"  WARNING: Missing {metric} for {model}/{seed}")
                        model_scores.append(np.nan)
                else:
                    print(f"  WARNING: Missing data for {model}/{seed}")
                    model_scores.append(np.nan)

            model_scores = np.array(model_scores)

            valid_mask = ~(np.isnan(baseline_scores) | np.isnan(model_scores))
            valid_baseline = baseline_scores[valid_mask]
            valid_model = model_scores[valid_mask]

            if len(valid_baseline) < 2:
                print(f"  ERROR: Not enough valid pairs (n={len(valid_baseline)})")
                continue

            baseline_mean = np.mean(valid_baseline)
            baseline_std = np.std(valid_baseline, ddof=1)
            model_mean = np.mean(valid_model)
            model_std = np.std(valid_model, ddof=1)
            mean_diff = baseline_mean - model_mean

            print(f"  {baseline_model}: {baseline_mean:.4f} ± {baseline_std:.4f}")
            print(f"  {model}: {model_mean:.4f} ± {model_std:.4f}")
            print(f"  Mean difference: {mean_diff:.4f}")

            try:
                t_stat, p_value = ttest_rel(valid_baseline, valid_model)
                print(f"  Paired t-test: t={t_stat:.4f}, p={p_value:.4g}")
            except Exception as e:
                print(f"  ERROR in t-test: {e}")
                t_stat, p_value = np.nan, np.nan

            try:
                d = cohens_d(valid_baseline, valid_model)
                d_interpretation = interpret_cohens_d(d)
                print(f"  Cohen's d: {d:.4f} ({d_interpretation} effect)")
            except Exception as e:
                print(f"  ERROR calculating Cohen's d: {e}")
                d, d_interpretation = np.nan, "N/A"

            try:
                _, ci_lower, ci_upper = bootstrap_ci(
                    valid_baseline, valid_model,
                    n_bootstrap=N_BOOTSTRAP,
                    ci_level=CI_LEVEL
                )
                ci_excludes_zero = (ci_lower > 0) or (ci_upper < 0)
                print(f"  Bootstrap {int(CI_LEVEL*100)}% CI: [{ci_lower:.4f}, {ci_upper:.4f}]")
                print(f"  CI excludes zero: {ci_excludes_zero}")
            except Exception as e:
                print(f"  ERROR in bootstrap: {e}")
                ci_lower, ci_upper = np.nan, np.nan
                ci_excludes_zero = False

            if not np.isnan(p_value):
                if p_value < 0.001:
                    significance_marker = "***"
                elif p_value < 0.01:
                    significance_marker = "**"
                elif p_value < 0.05:
                    significance_marker = "*"
                else:
                    significance_marker = "ns"
                is_significant = p_value < 0.05
            else:
                significance_marker = "N/A"
                is_significant = False

            print(f"  Significant: {is_significant} ({significance_marker})")

            results.append({
                'Metric': metric,
                'Comparison': f'{baseline_model} vs {model}',
                'Model': model,
                'Baseline_Mean': baseline_mean,
                'Baseline_Std': baseline_std,
                'Model_Mean': model_mean,
                'Model_Std': model_std,
                'Mean_Diff': mean_diff,
                'n_pairs': len(valid_baseline),
                't_statistic': t_stat,
                'p_value': p_value,
                'Cohens_d': d,
                'Effect_Size': d_interpretation,
                'Boot_CI_Lower': ci_lower,
                'Boot_CI_Upper': ci_upper,
                'CI_Excludes_Zero': ci_excludes_zero,
                'Significant': is_significant,
                'Significance': significance_marker
            })

    return pd.DataFrame(results)


def save_results(results_df, output_prefix='paired_ttest'):
    detailed_output = f'{output_prefix}_detailed.csv'
    results_df.to_csv(detailed_output, index=False)
    print(f"\nDetailed results saved to: {detailed_output}")

    print("\n" + "="*70)
    print("SUMMARY TABLE (Grouped by Metric)")
    print("="*70)

    for metric in results_df['Metric'].unique():
        metric_df = results_df[results_df['Metric'] == metric]
        print(f"\n{metric}:")
        display_cols = ['Model', 'Mean_Diff', 'p_value', 'Cohens_d',
                       'Boot_CI_Lower', 'Boot_CI_Upper', 'CI_Excludes_Zero', 'Significance']
        print(metric_df[display_cols].to_string(index=False))

    summary_rows = []
    for _, row in results_df.iterrows():
        summary_rows.append({
            'Metric': row['Metric'],
            'Model': row['Model'],
            'Baseline': f"{row['Baseline_Mean']:.4f} ± {row['Baseline_Std']:.4f}",
            'Model_Score': f"{row['Model_Mean']:.4f} ± {row['Model_Std']:.4f}",
            'Diff': f"{row['Mean_Diff']:.4f}",
            'p-value': f"{row['p_value']:.4g}" if not np.isnan(row['p_value']) else "N/A",
            "Cohen's d": f"{row['Cohens_d']:.4f}" if not np.isnan(row['Cohens_d']) else "N/A",
            f'{int(CI_LEVEL*100)}% CI': f"[{row['Boot_CI_Lower']:.4f}, {row['Boot_CI_Upper']:.4f}]" if not np.isnan(row['Boot_CI_Lower']) else "N/A",
            'CI_Sig': '✓' if row['CI_Excludes_Zero'] else '✗',
            'Sig': row['Significance']
        })

    summary_df = pd.DataFrame(summary_rows)
    summary_output = f'{output_prefix}_summary.csv'
    summary_df.to_csv(summary_output, index=False)
    print(f"\nFormatted summary saved to: {summary_output}")

    return summary_df


# ========== MAIN ==========
def main():
    print("="*70)
    print("LOADING SCORES FOR PAIRED T-TEST ANALYSIS WITH BOOTSTRAP CI")
    print("="*70)

    all_scores = load_all_scores(MODEL_CONFIGS)

    print(f"\nLoaded data for {len(all_scores)} models:")
    for model in sorted(all_scores.keys()):
        n_seeds = len(all_scores[model])
        print(f"  {model}: {n_seeds} seeds")

    results_df = perform_paired_ttest_analysis(all_scores, baseline_model='TITAN')

    summary_df = save_results(results_df, output_prefix='corpus_paired_ttest_with_bootstrap_titan')

    print("\n" + "="*70)
    print("ANALYSIS COMPLETE")
    print("="*70)

    return results_df, summary_df


# ========== RUN ==========
if __name__ == "__main__":
    results_df, summary_df = main()
# Out:
# ======================================================================
# LOADING SCORES FOR PAIRED T-TEST ANALYSIS WITH BOOTSTRAP CI
# ======================================================================
#
# Loaded data for 4 models:
#   CONCH: 5 seeds
#   TITAN: 5 seeds
#   UNI: 5 seeds
#   UNI2: 5 seeds
# ======================================================================
# PAIRED T-TEST ANALYSIS WITH BOOTSTRAP CI (Baseline: TITAN)
# ======================================================================
#
# Seeds: ['seed43', 'seed44', 'seed45', 'seed456789', 'seed46']
# Number of seeds: 5
# Bootstrap iterations: 10000
# Confidence level: 95.0%
#
#
# ======================================================================
# Metric: test_BLEU_1
# ======================================================================
#
# --- TITAN vs CONCH ---
#   TITAN: 0.7394 ± 0.0426
#   CONCH: 0.7231 ± 0.0226
#   Mean difference: 0.0163
#   Paired t-test: t=0.8602, p=0.4382
#   Cohen's d: 0.3847 (small effect)
#   Bootstrap 95% CI: [-0.0157, 0.0493]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI ---
#   TITAN: 0.7394 ± 0.0426
#   UNI: 0.7207 ± 0.0320
#   Mean difference: 0.0187
#   Paired t-test: t=0.8665, p=0.4351
#   Cohen's d: 0.3875 (small effect)
#   Bootstrap 95% CI: [-0.0207, 0.0542]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI2 ---
#   TITAN: 0.7394 ± 0.0426
#   UNI2: 0.7402 ± 0.0276
#   Mean difference: -0.0009
#   Paired t-test: t=-0.0422, p=0.9684
#   Cohen's d: -0.0189 (negligible effect)
#   Bootstrap 95% CI: [-0.0349, 0.0332]
#   CI excludes zero: False
#   Significant: False (ns)
#
# ======================================================================
# Metric: test_BLEU_2
# ======================================================================
#
# --- TITAN vs CONCH ---
#   TITAN: 0.7034 ± 0.0408
#   CONCH: 0.6852 ± 0.0222
#   Mean difference: 0.0181
#   Paired t-test: t=1.0113, p=0.3691
#   Cohen's d: 0.4523 (small effect)
#   Bootstrap 95% CI: [-0.0120, 0.0507]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI ---
#   TITAN: 0.7034 ± 0.0408
#   UNI: 0.6831 ± 0.0316
#   Mean difference: 0.0202
#   Paired t-test: t=0.9794, p=0.3828
#   Cohen's d: 0.4380 (small effect)
#   Bootstrap 95% CI: [-0.0171, 0.0543]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI2 ---
#   TITAN: 0.7034 ± 0.0408
#   UNI2: 0.7018 ± 0.0292
#   Mean difference: 0.0016
#   Paired t-test: t=0.0797, p=0.9403
#   Cohen's d: 0.0356 (negligible effect)
#   Bootstrap 95% CI: [-0.0325, 0.0345]
#   CI excludes zero: False
#   Significant: False (ns)
#
# ======================================================================
# Metric: test_BLEU_3
# ======================================================================
#
# --- TITAN vs CONCH ---
#   TITAN: 0.6703 ± 0.0375
#   CONCH: 0.6512 ± 0.0215
#   Mean difference: 0.0191
#   Paired t-test: t=1.1537, p=0.3129
#   Cohen's d: 0.5160 (medium effect)
#   Bootstrap 95% CI: [-0.0085, 0.0487]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI ---
#   TITAN: 0.6703 ± 0.0375
#   UNI: 0.6495 ± 0.0301
#   Mean difference: 0.0207
#   Paired t-test: t=1.0791, p=0.3413
#   Cohen's d: 0.4826 (small effect)
#   Bootstrap 95% CI: [-0.0137, 0.0525]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI2 ---
#   TITAN: 0.6703 ± 0.0375
#   UNI2: 0.6675 ± 0.0302
#   Mean difference: 0.0027
#   Paired t-test: t=0.1456, p=0.8913
#   Cohen's d: 0.0651 (negligible effect)
#   Bootstrap 95% CI: [-0.0278, 0.0333]
#   CI excludes zero: False
#   Significant: False (ns)
#
# ======================================================================
# Metric: test_BLEU_4
# ======================================================================
#
# --- TITAN vs CONCH ---
#   TITAN: 0.6428 ± 0.0342
#   CONCH: 0.6238 ± 0.0209
#   Mean difference: 0.0190
#   Paired t-test: t=1.2460, p=0.2808
#   Cohen's d: 0.5572 (medium effect)
#   Bootstrap 95% CI: [-0.0061, 0.0469]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI ---
#   TITAN: 0.6428 ± 0.0342
#   UNI: 0.6220 ± 0.0288
#   Mean difference: 0.0207
#   Paired t-test: t=1.1601, p=0.3105
#   Cohen's d: 0.5188 (medium effect)
#   Bootstrap 95% CI: [-0.0121, 0.0504]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI2 ---
#   TITAN: 0.6428 ± 0.0342
#   UNI2: 0.6396 ± 0.0310
#   Mean difference: 0.0032
#   Paired t-test: t=0.1802, p=0.8657
#   Cohen's d: 0.0806 (negligible effect)
#   Bootstrap 95% CI: [-0.0250, 0.0326]
#   CI excludes zero: False
#   Significant: False (ns)
#
# ======================================================================
# Metric: test_METEOR
# ======================================================================
#
# --- TITAN vs CONCH ---
#   TITAN: 0.4666 ± 0.0222
#   CONCH: 0.4540 ± 0.0144
#   Mean difference: 0.0127
#   Paired t-test: t=1.2467, p=0.2805
#   Cohen's d: 0.5575 (medium effect)
#   Bootstrap 95% CI: [-0.0030, 0.0307]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI ---
#   TITAN: 0.4666 ± 0.0222
#   UNI: 0.4504 ± 0.0203
#   Mean difference: 0.0162
#   Paired t-test: t=1.7358, p=0.1576
#   Cohen's d: 0.7763 (medium effect)
#   Bootstrap 95% CI: [-0.0009, 0.0314]
#   CI excludes zero: False
#   Significant: False (ns)
#
# --- TITAN vs UNI2 ---
#   TITAN: 0.4666 ± 0.0222
#   UNI2: 0.4635 ± 0.0195
#   Mean difference: 0.0031
#   Paired t-test: t=0.2411, p=0.8213
#   Cohen's d: 0.1078 (negligible effect)
#   Bootstrap 95% CI: [-0.0220, 0.0241]
#   CI excludes zero: False
#   Significant: False (ns)
#
# ======================================================================
# Metric: test_ROUGE_L
# ======================================================================
#
# --- TITAN vs CONCH ---
#   TITAN: 0.7600 ± 0.0246
#   CONCH: 0.6994 ± 0.0201
#   Mean difference: 0.0606
#   Paired t-test: t=6.6554, p=0.002647
#   Cohen's d: 2.9764 (large effect)
#   Bootstrap 95% CI: [0.0466, 0.0773]
#   CI excludes zero: True
#   Significant: True (**)
#
# --- TITAN vs UNI ---
#   TITAN: 0.7600 ± 0.0246
#   UNI: 0.6936 ± 0.0223
#   Mean difference: 0.0664
#   Paired t-test: t=5.7942, p=0.004411
#   Cohen's d: 2.5912 (large effect)
#   Bootstrap 95% CI: [0.0470, 0.0849]
#   CI excludes zero: True
#   Significant: True (**)
#
# --- TITAN vs UNI2 ---
#   TITAN: 0.7600 ± 0.0246
#   UNI2: 0.7141 ± 0.0262
#   Mean difference: 0.0459
#   Paired t-test: t=2.7860, p=0.04952
#   Cohen's d: 1.2459 (large effect)
#   Bootstrap 95% CI: [0.0179, 0.0738]
#   CI excludes zero: True
#   Significant: True (*)
#
# Detailed results saved to: corpus_paired_ttest_with_bootstrap_titan_detailed.csv
#
# ======================================================================
# SUMMARY TABLE (Grouped by Metric)
# ======================================================================
#
# test_BLEU_1:
# Model  Mean_Diff  p_value  Cohens_d  Boot_CI_Lower  Boot_CI_Upper  CI_Excludes_Zero Significance
# CONCH   0.016294 0.438181  0.384693      -0.015692       0.049311             False           ns
#   UNI   0.018737 0.435120  0.387492      -0.020681       0.054182             False           ns
#  UNI2  -0.000855 0.968379 -0.018862      -0.034891       0.033181             False           ns
#
# test_BLEU_2:
# Model  Mean_Diff  p_value  Cohens_d  Boot_CI_Lower  Boot_CI_Upper  CI_Excludes_Zero Significance
# CONCH   0.018117 0.369060  0.452285      -0.012000       0.050749             False           ns
#   UNI   0.020248 0.382849  0.437988      -0.017080       0.054284             False           ns
#  UNI2   0.001584 0.940322  0.035632      -0.032481       0.034513             False           ns
#
# test_BLEU_3:
# Model  Mean_Diff  p_value  Cohens_d  Boot_CI_Lower  Boot_CI_Upper  CI_Excludes_Zero Significance
# CONCH   0.019067 0.312856  0.515962      -0.008467       0.048737             False           ns
#   UNI   0.020727 0.341288  0.482566      -0.013669       0.052525             False           ns
#  UNI2   0.002737 0.891259  0.065127      -0.027788       0.033263             False           ns
#
# test_BLEU_4:
# Model  Mean_Diff  p_value  Cohens_d  Boot_CI_Lower  Boot_CI_Upper  CI_Excludes_Zero Significance
# CONCH   0.018974 0.280774  0.557206      -0.006133       0.046929             False           ns
#   UNI   0.020743 0.310534  0.518812      -0.012147       0.050384             False           ns
#  UNI2   0.003197 0.865736  0.080601      -0.025041       0.032631             False           ns
#
# test_METEOR:
# Model  Mean_Diff  p_value  Cohens_d  Boot_CI_Lower  Boot_CI_Upper  CI_Excludes_Zero Significance
# CONCH   0.012664 0.280540  0.557524      -0.002963       0.030671             False           ns
#   UNI   0.016222 0.157617  0.776256      -0.000908       0.031430             False           ns
#  UNI2   0.003137 0.821309  0.107838      -0.022033       0.024062             False           ns
#
# test_ROUGE_L:
# Model  Mean_Diff  p_value  Cohens_d  Boot_CI_Lower  Boot_CI_Upper  CI_Excludes_Zero Significance
# CONCH   0.060615 0.002647  2.976386       0.046585       0.077259              True           **
#   UNI   0.066443 0.004411  2.591230       0.046970       0.084914              True           **
#  UNI2   0.045859 0.049516  1.245918       0.017898       0.073821              True            *
#
# Formatted summary saved to: corpus_paired_ttest_with_bootstrap_titan_summary.csv
#
# ======================================================================
# ANALYSIS COMPLETE
# ======================================================================
